# %%
install.packages(c("MASS", "collapse", "lattice"), dependencies = TRUE)
install.packages("plm", dependencies = TRUE)
# Out:
# Warning message:
# "packages 'MASS', 'collapse', 'lattice' are not available (for R version 3.6.1)"Warning message:
# "unable to access index for repository https://cran.r-project.org/bin/windows/contrib/3.6:
#   cannot open URL 'https://cran.r-project.org/bin/windows/contrib/3.6/PACKAGES'"Warning message:
# "dependencies 'MASS', 'collapse', 'lattice', 'mgcv', 'pbkrtest', 'scales', 'Matrix', 'rlang', 'fs', 'rappdirs' are not available"also installing the dependencies 'sys', 'askpass', 'cli', 'SparseM', 'MatrixModels', 'minqa', 'nloptr', 'reformulas', 'RcppEigen', 'curl', 'mime', 'openssl', 'cachem', 'fastmap', 'lifecycle', 'memoise', 'sass', 'rbibutils', 'survival', 'nnet', 'quantreg', 'lme4', 'httr', 'highr', 'xfun', 'yaml', 'bslib', 'fontawesome', 'htmltools', 'tinytex', 'Rcpp', 'dreamerr', 'stringmagic', 'bdsmatrix', 'zoo', 'nlme', 'sandwich', 'lmtest', 'maxLik', 'Rdpack', 'AER', 'car', 'statmod', 'urca', 'pder', 'texreg', 'knitr', 'rmarkdown', 'fixest', 'lfe'
#
# ...

# %%
library("plm")
# Chạy mô hình Random Effects
model <- plm(Velocity ~ Street_Level, 
             data = your_data, 
             index = c("ID", "Time"), 
             model = "random")

summary(model)
# Out:
# Your code contains a unicode char which cannot be displayed in your
# current locale and R will silently convert it to an escaped form when the
# R kernel executes this code. This can lead to subtle errors if you use
# such chars to do comparisons. For more information, please see
# https://github.com/IRkernel/repr/wiki/Problems-with-unicode-on-windows
# Error in library("plm"): there is no package called 'plm'
# Traceback:
#
# 1. library("plm")
