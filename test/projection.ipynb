# %%
from pyproj import Transformer

# %%
transformer = Transformer.from_crs(
    "EPSG:4326",
    "EPSG:32648",
    always_xy=True
)

# %%
x, y = transformer.transform(106.6290559,10.8042433)
x, y
# Out:
# (678103.1816230624, 1194809.3812030535)
